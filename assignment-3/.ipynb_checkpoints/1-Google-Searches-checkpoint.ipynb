# %%
import os
import time
import numpy as np
import pandas as pd
import subprocess

# %%
#no of words pair
LEN = 353

# %%
with open('combined.csv') as f:
    read_data = f.read()

# %%
#words: (w1, w2), score: similarity score
dic = {'words': [],
      'score': []}
for idx, line in enumerate(read_data.split('\n')):
    
    if idx<= LEN and idx != 0:
        wordls = line.split(',')
        
        dic['words'].append( (wordls[0], wordls[1]) )
        dic['score'].append(float(wordls[2]))

# %%
stats_ls = []
count = 0

# %%
word_ls = dic['words']


while count != LEN:
    item = word_ls[count]
    k1, k2, k3 = item[0], item[1] , item[0] + "+" + item[1]
    keyls = [k1, k2, k3]
    
    temp_ls = []
    for keyword in keyls:
        res = subprocess.check_output(["wget", "-U", "Firefox/3.0.15", "http://www.google.com/search?q=" + keyword, "-O", "file.html"])

        with open('file.html', 'r',encoding = 'latin-1') as f:
            html_data = f.read()

        number = html_data.split("<div class=\"sd\" id=\"resultStats\">About ")[1].split(' ')[0].replace(',', '')
        temp_ls.append(number)
        time.sleep(2)
        
    count = count + 1
    stats_ls.append(temp_ls)
    print("Processing Complete: word pair no: ", count)
# Out:
# Processing Complete: word pair no:  1
# Processing Complete: word pair no:  2
# Processing Complete: word pair no:  3
# Processing Complete: word pair no:  4
# Processing Complete: word pair no:  5
# Processing Complete: word pair no:  6
# Processing Complete: word pair no:  7
# Processing Complete: word pair no:  8
# Processing Complete: word pair no:  9
# Processing Complete: word pair no:  10
# Processing Complete: word pair no:  11
# Processing Complete: word pair no:  12
# Processing Complete: word pair no:  13
# Processing Complete: word pair no:  14
# Processing Complete: word pair no:  15
# Processing Complete: word pair no:  16
# Processing Complete: word pair no:  17
# Processing Complete: word pair no:  18
# Processing Complete: word pair no:  19
# Processing Complete: word pair no:  20
# Processing Complete: word pair no:  21
# Processing Complete: word pair no:  22
# Processing Complete: word pair no:  23
# Processing Complete: word pair no:  24
# Processing Complete: word pair no:  25
# Processing Complete: word pair no:  26
# Processing Complete: word pair no:  27
# Processing Complete: word pair no:  28
# Processing Complete: word pair no:  29
# Processing Complete: word pair no:  30
# Processing Complete: word pair no:  31
# Processing Complete: word pair no:  32
# Processing Complete: word pair no:  33
# Processing Complete: word pair no:  34
# Processing Complete: word pair no:  35
# Processing Complete: word pair no:  36
# Processing Complete: word pair no:  37
# Processing Complete: word pair no:  38
# Processing Complete: word pair no:  39
# Processing Complete: word pair no:  40
# Processing Complete: word pair no:  41
# Processing Complete: word pair no:  42
# Processing Complete: word pair no:  43
# Processing Complete: word pair no:  44
# Processing Complete: word pair no:  45
# Processing Complete: word pair no:  46
# Processing Complete: word pair no:  47
# Processing Complete: word pair no:  48
# Processing Complete: word pair no:  49
# Processing Complete: word pair no:  50
# Processing Complete: word pair no:  51
# Processing Complete: word pair no:  52
# Processing Complete: word pair no:  53
# Processing Complete: word pair no:  54
# Processing Complete: word pair no:  55
# Processing Complete: word pair no:  56
# Processing Complete: word pair no:  57
# Processing Complete: word pair no:  58
# Processing Complete: word pair no:  59
# Processing Complete: word pair no:  60
# Processing Complete: word pair no:  61
# Processing Complete: word pair no:  62
# Processing Complete: word pair no:  63
# Processing Complete: word pair no:  64
# Processing Complete: word pair no:  65
# Processing Complete: word pair no:  66
# Processing Complete: word pair no:  67
# Processing Complete: word pair no:  68
# Processing Complete: word pair no:  69
# Processing Complete: word pair no:  70
# Processing Complete: word pair no:  71
# Processing Complete: word pair no:  72
# Processing Complete: word pair no:  73
# Processing Complete: word pair no:  74
# Processing Complete: word pair no:  75
# Processing Complete: word pair no:  76
# Processing Complete: word pair no:  77
# Processing Complete: word pair no:  78
# Processing Complete: word pair no:  79
# Processing Complete: word pair no:  80
# Processing Complete: word pair no:  81
# Processing Complete: word pair no:  82
# Processing Complete: word pair no:  83
# Processing Complete: word pair no:  84
# Processing Complete: word pair no:  85
# Processing Complete: word pair no:  86
# Processing Complete: word pair no:  87
# Processing Complete: word pair no:  88
# Processing Complete: word pair no:  89
# Processing Complete: word pair no:  90
# Processing Complete: word pair no:  91
# Processing Complete: word pair no:  92
# Processing Complete: word pair no:  93
# Processing Complete: word pair no:  94
# Processing Complete: word pair no:  95
# Processing Complete: word pair no:  96
# Processing Complete: word pair no:  97
# Processing Complete: word pair no:  98
# Processing Complete: word pair no:  99
# Processing Complete: word pair no:  100
# Processing Complete: word pair no:  101
# Processing Complete: word pair no:  102
# Processing Complete: word pair no:  103
# Processing Complete: word pair no:  104
# Processing Complete: word pair no:  105
# Processing Complete: word pair no:  106
# Processing Complete: word pair no:  107
# Processing Complete: word pair no:  108
# Processing Complete: word pair no:  109
# Processing Complete: word pair no:  110
# Processing Complete: word pair no:  111
# Processing Complete: word pair no:  112
# Processing Complete: word pair no:  113
# Processing Complete: word pair no:  114
# Processing Complete: word pair no:  115
# Processing Complete: word pair no:  116
# Processing Complete: word pair no:  117
# Processing Complete: word pair no:  118
# Processing Complete: word pair no:  119
# Processing Complete: word pair no:  120
# Processing Complete: word pair no:  121
# Processing Complete: word pair no:  122
# Processing Complete: word pair no:  123
# Processing Complete: word pair no:  124
# Processing Complete: word pair no:  125
# Processing Complete: word pair no:  126
# Processing Complete: word pair no:  127
# Processing Complete: word pair no:  128
# Processing Complete: word pair no:  129
# Processing Complete: word pair no:  130
# Processing Complete: word pair no:  131
# Processing Complete: word pair no:  132
# Processing Complete: word pair no:  133
# Processing Complete: word pair no:  134
# Processing Complete: word pair no:  135
# Processing Complete: word pair no:  136
# Processing Complete: word pair no:  137
# Processing Complete: word pair no:  138
# Processing Complete: word pair no:  139
# Processing Complete: word pair no:  140
# Processing Complete: word pair no:  141
# Processing Complete: word pair no:  142
# Processing Complete: word pair no:  143
# Processing Complete: word pair no:  144
# Processing Complete: word pair no:  145
# Processing Complete: word pair no:  146
# Processing Complete: word pair no:  147
# Processing Complete: word pair no:  148
# Processing Complete: word pair no:  149
# Processing Complete: word pair no:  150
# Processing Complete: word pair no:  151
# Processing Complete: word pair no:  152
# Processing Complete: word pair no:  153
# Processing Complete: word pair no:  154
# Processing Complete: word pair no:  155
# Processing Complete: word pair no:  156
# Processing Complete: word pair no:  157
# Processing Complete: word pair no:  158
# Processing Complete: word pair no:  159
# Processing Complete: word pair no:  160
# Processing Complete: word pair no:  161
# Processing Complete: word pair no:  162
# Processing Complete: word pair no:  163
# Processing Complete: word pair no:  164
# Processing Complete: word pair no:  165
# Processing Complete: word pair no:  166
# Processing Complete: word pair no:  167
# Processing Complete: word pair no:  168
# Processing Complete: word pair no:  169
# Processing Complete: word pair no:  170
# Processing Complete: word pair no:  171
# Processing Complete: word pair no:  172
# Processing Complete: word pair no:  173
# Processing Complete: word pair no:  174
# Processing Complete: word pair no:  175
# Processing Complete: word pair no:  176
# Processing Complete: word pair no:  177
# Processing Complete: word pair no:  178
# Processing Complete: word pair no:  179
# Processing Complete: word pair no:  180
# Processing Complete: word pair no:  181
# Processing Complete: word pair no:  182
# Processing Complete: word pair no:  183
# Processing Complete: word pair no:  184
# Processing Complete: word pair no:  185
# Processing Complete: word pair no:  186
# Processing Complete: word pair no:  187
# Processing Complete: word pair no:  188
# Processing Complete: word pair no:  189
# Processing Complete: word pair no:  190
# Processing Complete: word pair no:  191
# Processing Complete: word pair no:  192
# Processing Complete: word pair no:  193
# Processing Complete: word pair no:  194
# Processing Complete: word pair no:  195
# Processing Complete: word pair no:  196
# Processing Complete: word pair no:  197
# Processing Complete: word pair no:  198
# Processing Complete: word pair no:  199
# Processing Complete: word pair no:  200
# Processing Complete: word pair no:  201
# Processing Complete: word pair no:  202
# Processing Complete: word pair no:  203
# Processing Complete: word pair no:  204
# Processing Complete: word pair no:  205
# Processing Complete: word pair no:  206
# Processing Complete: word pair no:  207
# Processing Complete: word pair no:  208
# Processing Complete: word pair no:  209
# Processing Complete: word pair no:  210
# Processing Complete: word pair no:  211
# Processing Complete: word pair no:  212
# Processing Complete: word pair no:  213
# Processing Complete: word pair no:  214
# Processing Complete: word pair no:  215
# Processing Complete: word pair no:  216
# Processing Complete: word pair no:  217
# Processing Complete: word pair no:  218
# Processing Complete: word pair no:  219
# Processing Complete: word pair no:  220
# Processing Complete: word pair no:  221
# Processing Complete: word pair no:  222
# Processing Complete: word pair no:  223
# Processing Complete: word pair no:  224
# Processing Complete: word pair no:  225
# Processing Complete: word pair no:  226
# Processing Complete: word pair no:  227
# Processing Complete: word pair no:  228
# Processing Complete: word pair no:  229
# Processing Complete: word pair no:  230
# Processing Complete: word pair no:  231
# Processing Complete: word pair no:  232
# Processing Complete: word pair no:  233
# Processing Complete: word pair no:  234
# Processing Complete: word pair no:  235
# Processing Complete: word pair no:  236
# Processing Complete: word pair no:  237
# Processing Complete: word pair no:  238
# Processing Complete: word pair no:  239
# Processing Complete: word pair no:  240
# Processing Complete: word pair no:  241
# Processing Complete: word pair no:  242
# Processing Complete: word pair no:  243
# Processing Complete: word pair no:  244
# Processing Complete: word pair no:  245
# Processing Complete: word pair no:  246
# Processing Complete: word pair no:  247
# Processing Complete: word pair no:  248
# Processing Complete: word pair no:  249
# Processing Complete: word pair no:  250
# Processing Complete: word pair no:  251
# Processing Complete: word pair no:  252
# Processing Complete: word pair no:  253
# Processing Complete: word pair no:  254
# Processing Complete: word pair no:  255
# Processing Complete: word pair no:  256
# Processing Complete: word pair no:  257
# Processing Complete: word pair no:  258
# Processing Complete: word pair no:  259
# Processing Complete: word pair no:  260
# Processing Complete: word pair no:  261
# Processing Complete: word pair no:  262
# Processing Complete: word pair no:  263
# Processing Complete: word pair no:  264
# Processing Complete: word pair no:  265
# Processing Complete: word pair no:  266
# Processing Complete: word pair no:  267
# Processing Complete: word pair no:  268
# Processing Complete: word pair no:  269
# Processing Complete: word pair no:  270
# Processing Complete: word pair no:  271
# Processing Complete: word pair no:  272
# Processing Complete: word pair no:  273
# Processing Complete: word pair no:  274
# Processing Complete: word pair no:  275
# Processing Complete: word pair no:  276
# Processing Complete: word pair no:  277
# Processing Complete: word pair no:  278
# Processing Complete: word pair no:  279
# Processing Complete: word pair no:  280
# Processing Complete: word pair no:  281
# Processing Complete: word pair no:  282
# Processing Complete: word pair no:  283
# Processing Complete: word pair no:  284
# Processing Complete: word pair no:  285
# Processing Complete: word pair no:  286
# Processing Complete: word pair no:  287
# Processing Complete: word pair no:  288
# Processing Complete: word pair no:  289
# Processing Complete: word pair no:  290
# Processing Complete: word pair no:  291
# Processing Complete: word pair no:  292
# Processing Complete: word pair no:  293
# Processing Complete: word pair no:  294
# Processing Complete: word pair no:  295
# Processing Complete: word pair no:  296
# Processing Complete: word pair no:  297
# Processing Complete: word pair no:  298
# Processing Complete: word pair no:  299
# Processing Complete: word pair no:  300
# Processing Complete: word pair no:  301
# Processing Complete: word pair no:  302
# Processing Complete: word pair no:  303
# Processing Complete: word pair no:  304
# Processing Complete: word pair no:  305
# Processing Complete: word pair no:  306
# Processing Complete: word pair no:  307
# Processing Complete: word pair no:  308
# Processing Complete: word pair no:  309
# Processing Complete: word pair no:  310
# Processing Complete: word pair no:  311
# Processing Complete: word pair no:  312
# Processing Complete: word pair no:  313
# Processing Complete: word pair no:  314
# Processing Complete: word pair no:  315
# Processing Complete: word pair no:  316
# Processing Complete: word pair no:  317
# Processing Complete: word pair no:  318
# Processing Complete: word pair no:  319
# Processing Complete: word pair no:  320
# Processing Complete: word pair no:  321
# Processing Complete: word pair no:  322
# Processing Complete: word pair no:  323
# Processing Complete: word pair no:  324
# Processing Complete: word pair no:  325
# Processing Complete: word pair no:  326
# Processing Complete: word pair no:  327
# Processing Complete: word pair no:  328
# Processing Complete: word pair no:  329
# Processing Complete: word pair no:  330
# Processing Complete: word pair no:  331
# Processing Complete: word pair no:  332
# Processing Complete: word pair no:  333
# Processing Complete: word pair no:  334
# Processing Complete: word pair no:  335
# Processing Complete: word pair no:  336
# Processing Complete: word pair no:  337
# Processing Complete: word pair no:  338
# Processing Complete: word pair no:  339
# Processing Complete: word pair no:  340
# Processing Complete: word pair no:  341
# Processing Complete: word pair no:  342
# Processing Complete: word pair no:  343
# Processing Complete: word pair no:  344
# Processing Complete: word pair no:  345
# Processing Complete: word pair no:  346
# Processing Complete: word pair no:  347
# Processing Complete: word pair no:  348
# Processing Complete: word pair no:  349
# Processing Complete: word pair no:  350
# Processing Complete: word pair no:  351
# Processing Complete: word pair no:  352
# Processing Complete: word pair no:  353

# %%
len(stats_ls)
# Out:
# 353

# %%
word_file = open('word-count.txt', 'w')
word_file.write("word-1 word-2 pair\n")


for l in stats_ls:
    word_file.write(l[0] + " " + l[1] + " " + l[2] + "\n")

word_file.close()
